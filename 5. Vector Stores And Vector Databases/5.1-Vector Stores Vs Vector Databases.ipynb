# %% [markdown]
# ---
# # Vector Stores Vs Vector Databases
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)![image-2.png](attachment:image-2.png) <br><br>
#
# ![image-3.png](attachment:image-3.png) <br><br>
#
# ![image-4.png](attachment:image-4.png)![image-5.png](attachment:image-5.png) <br><br>
#
# ![image-6.png](attachment:image-6.png)
#
# ----
